# %% [markdown]
# <a href="https://colab.research.google.com/github/designer24-7/Data110/blob/main/Week-3_Task-1_Plotting-Sine-and-Cosine-Curves.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
import plotly as pt
import pandas as pd  ##for dataframes
import seaborn as sn ##for Heatmaps

# %%
# Generate a sequence of 1000 evenly spaced numbers from -2π to 2π
#linespace is very useful, since
x = np.linspace(-2 * np.pi, 2 * np.pi)

# Calculate the sine of these numbers
y1 = np.sin(x)
y2 = np.cos(x)

# Plot the sine and cosine waves
style=("ggplot")
plt.figure(figsize=(16,9))

plt.plot(x, y1, label='sin(x)', color="blue", linewidth=3)
plt.plot(x, y2, label='cos(x)', color="orange", linewidth=3)
plt.title('Plotting Sine and Cosine Curves', fontsize=26, pad=32)
plt.xlabel('x'
plt.ylabel('y')
plt.legend(loc="lower left", )
plt.grid(True, axis="y", color="gray" )
plt.show()

# %%
grouped_data
# Out:
#     Fruit  Quantity
# 0   Apple        10
# 1  Banana         5
# 2   Apple         8
# 3  Banana        12
# 4  Cherry         7
